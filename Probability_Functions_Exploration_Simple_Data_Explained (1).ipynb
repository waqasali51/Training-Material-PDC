# %% [markdown]
# # Exploring Probability Functions
#
# In this notebook, we will comprehensively explore and explain the following functions:
# - Probability Mass Function (PMF)
# - Cumulative Distribution Function (CDF)
# - Probability Density Function (PDF)
#
# We will use simple data and datasets to demonstrate these concepts. For each function, we will provide a simple mathematical representation, an explanation of the calculation, and a graphical representation.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import gaussian_kde

# Setting Seaborn style for better aesthetics
sns.set(style="whitegrid")

# %% [markdown]
# ## Probability Mass Function (PMF)
#
# The Probability Mass Function (PMF) is a function that gives the probability that a discrete random variable is exactly equal to some value.
#
# ### Mathematical Representation
#
# Mathematical Representation: If
# 𝑋
# X is a discrete random variable, the PMF is
#
# P(X=x).
#
# ### Example with a Simple Dataset
#
# Consider a dataset representing the number of heads obtained when flipping a coin three times.
#
# ### Calculation and Graph
#
# ```python
# # Simple dataset: number of heads in 3 coin flips
# data = [0, 1, 2, 3]
# counts = [1, 3, 3, 1]  # Corresponding counts from 3 coin flips
#
# # Calculate PMF
# total_flips = sum(counts)
# pmf = [count / total_flips for count in counts]
#
# plt.figure(figsize=(10, 6))
# plt.stem(data, pmf, basefmt=" ", use_line_collection=True)
# plt.title('PMF of Number of Heads in 3 Coin Flips')
# plt.xlabel('Number of Heads')
# plt.ylabel('Probability')
# plt.show()
# ```
#
# In this example, the PMF shows the probability of getting 0, 1, 2, or 3 heads when flipping a coin three times.

# %%
# Simple dataset: number of heads in 3 coin flips
data = [0, 1, 2, 3]
counts = [1, 3, 3, 1]  # Corresponding counts from 3 coin flips

# Calculate PMF
total_flips = sum(counts)
pmf = [count / total_flips for count in counts]

plt.figure(figsize=(10, 6))
plt.stem(data, pmf, basefmt=" ", use_line_collection=True)
plt.title('PMF of Number of Heads in 3 Coin Flips')
plt.xlabel('Number of Heads')
plt.ylabel('Probability')
plt.show()
# Out:
# <ipython-input-2-77856abfeba2>:10: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(data, pmf, basefmt=" ", use_line_collection=True)

# %% [markdown]
# ## Cumulative Distribution Function (CDF)
#
# The Cumulative Distribution Function (CDF) is a function that gives the probability that a random variable is less than or equal to a certain value.
#
# ### Mathematical Representation
#
# Mathematical Representation: If
# 𝑋
# X is a random variable, the CDF is
#
# F(x)=P(X≤x).
#
# ### Example with a Simple Dataset
#
# Consider a dataset representing the scores of students in a test.
#
# ### Calculation and Graph
#
# ```python
# # Simple dataset: student scores
# scores = [55, 60, 65, 70, 75, 80, 85, 90, 95, 100]
#
# # Calculate CDF
# sorted_scores = np.sort(scores)
# cdf = np.arange(1, len(sorted_scores) + 1) / len(sorted_scores)
#
# plt.figure(figsize=(10, 6))
# plt.step(sorted_scores, cdf, where='post')
# plt.title('CDF of Student Scores')
# plt.xlabel('Score')
# plt.ylabel('Cumulative Probability')
# plt.show()
# ```
#
# In this example, the CDF shows the cumulative probability of a student scoring less than or equal to a particular score.

# %%
# Simple dataset: student scores
scores = [55, 60, 65, 70, 75, 80, 85, 90, 95, 100]

# Calculate CDF
sorted_scores = np.sort(scores)
cdf = np.arange(1, len(sorted_scores) + 1) / len(sorted_scores)

plt.figure(figsize=(10, 6))
plt.step(sorted_scores, cdf, where='post')
plt.title('CDF of Student Scores')
plt.xlabel('Score')
plt.ylabel('Cumulative Probability')
plt.show()

# %% [markdown]
# ## Probability Density Function (PDF)
#
# The Probability Density Function (PDF) is a function that describes the likelihood of a continuous random variable to take on a particular value.
#
# ### Mathematical Representation
#
# For a continuous random variable \(X\) with density function \(f(x)\), the PDF is given by:
# \[ f(x) \]
#
# Mathematical Representation: If
# 𝑋
# X is a continuous random variable, the PDF is
# 𝑓
# (
# 𝑥
# )
# f(x). The probability that
# 𝑋
# X falls within an interval
# [
# 𝑎
# ,
# 𝑏
# ]
# [a,b] is given by the area under the curve of the PDF between
# 𝑎
#  and
# 𝑏
#
# P(a≤X≤b)=∫
# a
# b
# ​
#  f(x)dx.
#
# ### Example with a Simple Dataset
#
# Consider a dataset representing the heights of individuals.
#
# ### Calculation and Graph
#
# ```python
# # Simple dataset: heights of individuals (in cm)
# heights = [150, 155, 160, 165, 170, 175, 180, 185, 190, 195]
#
# # Estimate PDF using a kernel density estimate
# kde = gaussian_kde(heights)
# x = np.linspace(min(heights), max(heights), 100)
# pdf = kde(x)
#
# plt.figure(figsize=(10, 6))
# plt.plot(x, pdf, 'blue')
# plt.title('PDF of Heights')
# plt.xlabel('Height (cm)')
# plt.ylabel('Density')
# plt.show()
# ```
#
# In this example, the PDF shows the likelihood of individuals having certain heights.

# %%
# Simple dataset: heights of individuals (in cm)
heights = [150, 155, 160, 165, 170, 175, 180, 185, 190, 195]

# Estimate PDF using a kernel density estimate
kde = gaussian_kde(heights)
x = np.linspace(min(heights), max(heights), 100)
pdf = kde(x)

plt.figure(figsize=(10, 6))
plt.plot(x, pdf, 'blue')
plt.title('PDF of Heights')
plt.xlabel('Height (cm)')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# Assuming Normal Distribution
#
# Calculate Mean (
# 𝜇
# μ): The average of the dataset.
#
# Calculate Standard Deviation (
# 𝜎
# ): The measure of the amount of variation in the dataset.
#
# Normal Distribution PDF Formula
#
# ![Screenshot 2024-06-28 135825.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Simple dataset: heights of individuals (in cm)
heights = [150, 155, 160, 165, 170, 175, 180, 185, 190, 195]

# Step 1: Calculate Mean and Standard Deviation
mean = np.mean(heights)
std_dev = np.std(heights)

# Step 2: Define the range of values for which we want to estimate the PDF
x_values = np.linspace(min(heights) - 10, max(heights) + 10, 1000)

# Step 3: Calculate the PDF using the normal distribution formula
pdf_values = norm.pdf(x_values, mean, std_dev)

# Plotting the PDF
plt.plot(x_values, pdf_values, color='blue', label='PDF')
plt.xlabel('Height (cm)')
plt.ylabel('Density')
plt.title('Estimated PDF of Heights')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Combined Example
#
# Let's look at all three functions together for a better understanding.
#
# ### Example with a Simple Dataset
#
# Consider a dataset representing the ages of individuals in a small group.
#
# ### Calculation and Graph
#
# ```python
# # Simple dataset: ages of individuals
# ages = [23, 23, 24, 24, 24, 25, 25, 26, 26, 27, 28, 29, 30]
#
# # PMF
# values, counts = np.unique(ages, return_counts=True)
# pmf = counts / len(ages)
#
# plt.figure(figsize=(18, 6))
#
# # PMF Plot
# plt.subplot(1, 3, 1)
# plt.stem(values, pmf, basefmt=" ", use_line_collection=True)
# plt.title('PMF of Ages')
# plt.xlabel('Age')
# plt.ylabel('Probability')
#
# # CDF
# sorted_ages = np.sort(ages)
# cdf = np.arange(1, len(sorted_ages) + 1) / len(sorted_ages)
# plt.subplot(1, 3, 2)
# plt.step(sorted_ages, cdf, where='post')
# plt.title('CDF of Ages')
# plt.xlabel('Age')
# plt.ylabel('Cumulative Probability')
#
# # PDF
# kde = gaussian_kde(ages)
# x = np.linspace(min(ages), max(ages), 100)
# pdf = kde(x)
# plt.subplot(1, 3, 3)
# plt.plot(x, pdf, 'blue')
# plt.title('PDF of Ages')
# plt.xlabel('Age')
# plt.ylabel('Density')
#
# plt.tight_layout()
# plt.show()
# ```
#
# In this example, the PMF, CDF, and PDF of the ages dataset are calculated and visualized for a comprehensive understanding of these functions.

# %%
# Simple dataset: ages of individuals
ages = [23, 23, 24, 24, 24, 25, 25, 26, 26, 27, 28, 29, 30]

# PMF
values, counts = np.unique(ages, return_counts=True)
pmf = counts / len(ages)

plt.figure(figsize=(18, 6))

# PMF Plot
plt.subplot(1, 3, 1)
plt.stem(values, pmf, basefmt=" ", use_line_collection=True)
plt.title('PMF of Ages')
plt.xlabel('Age')
plt.ylabel('Probability')

# CDF
sorted_ages = np.sort(ages)
cdf = np.arange(1, len(sorted_ages) + 1) / len(sorted_ages)
plt.subplot(1, 3, 2)
plt.step(sorted_ages, cdf, where='post')
plt.title('CDF of Ages')
plt.xlabel('Age')
plt.ylabel('Cumulative Probability')

# PDF
kde = gaussian_kde(ages)
x = np.linspace(min(ages), max(ages), 100)
pdf = kde(x)
plt.subplot(1, 3, 3)
plt.plot(x, pdf, 'blue')
plt.title('PDF of Ages')
plt.xlabel('Age')
plt.ylabel('Density')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-5-0a67686a475c>:12: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(values, pmf, basefmt=" ", use_line_collection=True)
